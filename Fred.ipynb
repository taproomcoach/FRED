# %%
# !pip install fredapi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import fredapi as fa
import seaborn as sns

plt.style.use('fivethirtyeight')

color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

from fredapi import Fred

fred_key = '00e678593b69e70f06fbfdeb7fbc7bc2'

# %%
fred = Fred(api_key=fred_key)

# %%
fred.search('s&p', order_by='popularity')
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2024-05-14   2024-05-14
# CSUSHPINSA              CSUSHPINSA     2024-05-14   2024-05-14
# SP500                        SP500     2024-05-14   2024-05-14
# MEHOINUSA672N        MEHOINUSA672N     2024-05-14   2024-05-14
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2024-05-14   2024-05-14
# ...                            ...            ...          ...
# DDDI12SMA156NWDB  DDDI12SMA156NWDB     2024-05-14   2024-05-14
# DDDI01GTA156NWDB  DDDI01GTA156NWDB     2024-05-14   2024-05-14
# Q03069USQ605NNBR  Q03069USQ605NNBR     2024-05-14   2024-05-14
# CSHXCPVEA156NRUG  CSHXCPVEA156NRUG     2024-05-14   2024-05-14
# CSHMCPNPA156NRUG  CSHMCPNPA156NRUG     2024-05-14   2024-05-14
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# ...

# %%
sp500 = fred.get_series(series_id='sp500')

# %%
sp500.plot(figsize=(10, 5), title = 'S&P 500', lw=1)
# Out:
# <Axes: title={'center': 'S&P 500'}>

# %%
fred.search('unemployment state', order_by = 'popularity')
# Out:
#                                           id realtime_start realtime_end  \
# series id
# CPIAUCSL                            CPIAUCSL     2024-05-10   2024-05-10
# UNRATE                                UNRATE     2024-05-10   2024-05-10
# PAYEMS                                PAYEMS     2024-05-10   2024-05-10
# ICSA                                    ICSA     2024-05-10   2024-05-10
# SAHMREALTIME                    SAHMREALTIME     2024-05-10   2024-05-10
# ...                                      ...            ...          ...
# M08320USM156SNBR            M08320USM156SNBR     2024-05-10   2024-05-10
# ORMULT1URN                        ORMULT1URN     2024-05-10   2024-05-10
# LAUST560000000000003A  LAUST560000000000003A     2024-05-10   2024-05-10
# LAUMT063290000000004    LAUMT063290000000004     2024-05-10   2024-05-10
# DAVE317UR                          DAVE317UR     2024-05-10   2024-05-10
#
#                                                                    title  \
# ...

# %%
PMSAVE = fred.get_series(series_id='PMSAVE')

# %%
PMSAVE.plot(figsize=(10, 5), title = 'Personal Savings', lw=1)
# Out:
# <Axes: title={'center': 'Personal Savings'}>

# %%
DFF = fred.get_series(series_id='DFF')

# %%
DFF.plot(figsize=(10, 5), title = 'Interest Rate', lw=1)
# Out:
# <Axes: title={'center': 'Interest Rate'}>

# %%
Sticky = fred.get_series(series_id='CORESTICKM159SFRBATL')

# %%
Sticky.plot(figsize=(10, 5), title = 'Sticky', lw=1)
# Out:
# <Axes: title={'center': 'Sticky'}>

# %%
guess=pd.concat([Sticky, PMSAVE])

# %%
guess.plot(kind = 'line', lw=1, xlabel = 'year', title = 'Joel Analysis')
# Out:
# <Axes: title={'center': 'Joel Analysis'}, xlabel='year'>
